# %%
import os

import numpy as np
import pandas as pd
import scipy as sp

# import tensorflow as tf
# from tensorflow.keras import Model, Input, losses, layers, optimizers

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
 
from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score
# from sklearn.metrics import f1_score

from matplotlib import pyplot as plt
# from matplotlib.colors import BoundaryNorm
# import seaborn as sns

# import itertools
from tqdm.auto import trange, tqdm

from pathlib import Path

# from src.datasets import adults
# from src.evaluation import data_benchmark
# from src.models import vae_keras
# from src.datasets import adults#, dataset_utils

# print(tf.config.list_physical_devices('GPU'))
# tf.debugging.set_log_device_placement(True)

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# import tensorflow as tf
# for gpu in tf.config.list_physical_devices('GPU'):
#     tf.config.experimental.set_memory_growth(gpu, True)

# %%
# 
# 

def editData(X, y): #samples_n per class
    # TODO
    return

# %% [markdown]
# ## Alternate shapes

# %%
x_cat = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_cat_train_backup.npy', allow_pickle=True)
x_num = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_num_train_backup.npy', allow_pickle=True)
y = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/y_train_backup.npy', allow_pickle=True)

print(type(y))
print(np.unique(y, return_counts=True))
print(x_cat.shape, x_num.shape, y.shape)

# x_train = np.concatenate([x_cat, x_num], axis=1)

# x_train_bal, y_train_bal= TrainSplitEqualBinary(x_train, y, 6273) 

# x_new_cat = x_train_bal[:,:8]
# x_new_num = x_train_bal[:,8:].astype(np.float32)
# y_new = y_train_bal


print(x_new_cat.shape, x_new_num.shape, y_new.shape)

np.save('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_cat_train.npy', x_new_cat[:,:8]) 
np.save('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_num_train.npy', x_new_num) 
np.save('/home/fjunpop/tab-ddpm-dp/data/adult_cont/y_train.npy', y_new) 


x_cat = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_cat_train.npy', allow_pickle=True)
x_num = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_num_train.npy', allow_pickle=True)
y = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/y_train.npy', allow_pickle=True)

print(x_cat.shape, x_num.shape, y.shape)


# print(x_train.shape)

# print(x_cat[:,-1])
# Out:
# <class 'numpy.ndarray'>
# (array([0, 1]), array([19775,  6273]))
# (26048, 8) (26048, 6) (26048,)
# (26048, 8) (26048, 6) (26048,)

# %% [markdown]
# ## Restore default datasets

# %%
x_cat = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_cat_train_backup.npy', allow_pickle=True)
x_num = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_num_train_backup.npy', allow_pickle=True)
y = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/y_train_backup.npy', allow_pickle=True)

print(x_cat.shape, x_num.shape, y.shape)


np.save('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_cat_train.npy', x_cat) 
np.save('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_num_train.npy', x_num) 
np.save('/home/fjunpop/tab-ddpm-dp/data/adult_cont/y_train.npy', y) 

x_cat = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_cat_train.npy', allow_pickle=True)
x_num = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_num_train.npy', allow_pickle=True)
y = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/y_train.npy', allow_pickle=True)

print(x_cat.shape, x_num.shape, y.shape)
# Out:
# (26048, 8) (26048, 6) (26048,)
# (26048, 8) (26048, 6) (26048,)

# %% [markdown]
# ## Check current shapes

# %%
x_cat = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_cat_train.npy', allow_pickle=True)
x_num = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/X_num_train.npy', allow_pickle=True)
y = np.load('/home/fjunpop/tab-ddpm-dp/data/adult_cont/y_train.npy', allow_pickle=True)

print(x_cat.shape, x_num.shape, y.shape)
# Out:
# (26048, 8) (26048, 6) (26048,)
